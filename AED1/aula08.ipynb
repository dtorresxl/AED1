# %%
import random

# %%
n = random.randint(1, 50)

# %%
print(n)
# Out:
# 45

# %%
def jogo_adivinhacao():
    numero_secreto = random.randint(1, 50)
    tentativas = 0

    print("Tente adivinhar o número entre 1 e 50.")

    while True:
        try:
            palpite = int(input("Digite seu palpite: "))

            if palpite < 1 or palpite > 50:
                print("Por favor, digite um número entre 1 e 50.")
                continue

            if palpite == numero_secreto:
                print(f"Parabéns! Você acertou.")
                break
            elif palpite < numero_secreto:
                print("O número é maior. Tente novamente.")
            else:
                print("O número é menor. Tente novamente.")
        except ValueError:
            print("Por favor, digite um número válido.")

if __name__ == "__main__":
    jogo_adivinhacao()
# Out:
# Tente adivinhar o número entre 1 e 50.
# Digite seu palpite:  20
# O número é maior. Tente novamente.
# Digite seu palpite:  40
# O número é menor. Tente novamente.
# Você ainda tem 5 tentativas.
# Digite seu palpite:  30
# O número é menor. Tente novamente.
# Você ainda tem 5 tentativas.
# Digite seu palpite:  25
# O número é maior. Tente novamente.
# Digite seu palpite:  27
# O número é maior. Tente novamente.
# Digite seu palpite:  26
# O número é maior. Tente novamente.
# Digite seu palpite:  28
# O número é maior. Tente novamente.
# Digite seu palpite:  29
# Parabéns! Você acertou em 0 tentativas.

# %%
import random

def jogo_adivinhacao():
    numero_secreto = random.randint(1, 50)
    tentativas = 0
    max_tentativas = 5

    print("Tente adivinhar o número entre 1 e 50.")
    print(f"Você tem no máximo {max_tentativas} tentativas.")

    while tentativas < max_tentativas:
        try:
            palpite = int(input("Digite seu palpite: "))

            if palpite < 1 or palpite > 50:
                print("Por favor, digite um número entre 1 e 50.")
                continue

            tentativas += 1

            if palpite == numero_secreto:
                print(f"Parabéns! Você acertou na tentativa {tentativas}.")
                break
            elif palpite < numero_secreto:
                print("O número é maior. Tente novamente.")
            else:
                print("O número é menor. Tente novamente.")
            
            print(f"Você ainda tem {max_tentativas - tentativas} tentativas.")
            
        except ValueError:
            print("Por favor, digite um número válido.")

    else:15
        print(f"Suas tentativas acabaram. O número era {numero_secreto}.")

if __name__ == "__main__":
    jogo_adivinhacao()
# Out:
# Tente adivinhar o número entre 1 e 50.
# Você tem no máximo 5 tentativas.
# Digite seu palpite:  25
# O número é menor. Tente novamente.
# Você ainda tem 4 tentativas.
# Digite seu palpite:  15
# O número é menor. Tente novamente.
# Você ainda tem 3 tentativas.
# Digite seu palpite:  8
# O número é menor. Tente novamente.
# Você ainda tem 2 tentativas.
# Digite seu palpite:  5
# O número é menor. Tente novamente.
# Você ainda tem 1 tentativas.
# Digite seu palpite:  3
# O número é maior. Tente novamente.
# Você ainda tem 0 tentativas.
# Suas tentativas acabaram. O número era 4.

# %%
while tentativa<5:
    palpite = (int(input("Digite um palpite:" )
                   if palpite == n_secreto :
                   print("Acertou, parabéns!")
                   break:
                   else:
               print("Errou!")
               if palpite > n_secreto:
                  print("Tente num n° menor")
               else:
    print("Tente um n° maior")
tentativa = tentativa + 1
# Out:
#   Cell In[1], line 2
#     palpite = (int(input("Digite um palpite:" )
#                   ^
# SyntaxError: '(' was never closed

# %%
import random
n = random.randint(1, 50)


for i in range (5):
    palpite = int(input("Digite um numero <1-50>: "))
    if palpite == n_secreto:
        print("Parabéns! Você acertou!!")
        break:
    else:
        if (palpite > (n_secreto - 5)) and (palpite < (n-secreto + 5)) :
        else:
            print("Está frio")
print ("Acabou!!")
# Out:
#   Cell In[3], line 9
#     break:
#          ^
# SyntaxError: invalid syntax
