# %%
x = int(input("digite o x: "))
y = int(input("digite o y: "))
soma = x + y
print ("A soma de x + y é:", soma)
# Out:
# digite o x:  12
# digite o y:  13
# A soma de x + y é: 25

# %%
idade = int(input("digite sua idade: "))
if idade >= 18 :
    print("você é maior de idade!")
else :
    print("você é menor de idade!")
# Out:
# digite sua idade:  15
# você é menor de idade!

# %%
carro = input("Tem carro? <S/N>")
if carro == "S":
    print("Você pode dirigir!")
else:
    print("Pede um uber!")
# Out:
# Tem carro? <S/N> S
# Você pode dirigir!

# %%
idade = int(input("Digite sua idade: "))
carro = input("Tem carro? <S/N> ")
if (idade >= 18) and (carro == "S"):
    print("Pode dirigir")
else:
    print("Chama um Uber!")
# Out:
# Digite sua idade:  18
# Tem carro? <S/N>  S
# Pode dirigir

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
    carro = input("Tem carro? <S/N> ")
    if carro == "S" :
        print("Pode dirigir!")
        print("Chama uber!")
    else:
     print("Chama uber!")
# Out:
# Digite sua idade:  20
# Tem carro? <S/N>  S
# Pode dirigir!
# Chama uber!

# %%
nota1 = float(input("Qual foi sua nota em matematica: "))
if nota1 >= 7:
    nota1 = nota1 + 0.5
nota2 = float(input("Qual foi sua nota em português: "))
if nota2 >= 7:
    nota2 = nota2 + 0.5
media = (nota1 + nota2)/2
if media >= 5:
    print("Você foi aprovado(a)! Sua media foi: ", media)
else:
    print("Você foi reprovado(a)!")
# Out:
# Qual foi sua nota em matematica:  7
# Qual foi sua nota em português:  7
# Você foi aprovado(a)! Sua media foi:  7.5

# %%
a = float(input("qual é a medida do a?: "))
b = float(input("qual é a medida do b?: "))
c = float(input("qual é a medida da c: "))
if (a >= b+c) or (b>= a+c) or (c >= a+b):
    print("Não é triangulo")
else :
    if (a == b == c):
        print("É um triangulo equilatero")
    elif (a == b) or (b == c) or (a == c):
        print("É um triangulo isoceles")
    else:
        print("É um triangulo escaleno")
# Out:
# qual é a medida do a?:  12
# qual é a medida do b?:  12
# qual é a medida da c:  12
# É um triangulo equilatero
