# %%
(3*y)/(5*y+7))+2*y

# %%
p = True
q = False
x = (p > q) and (not(p == q))
print ("o x é:", x)
# Out:
# o x é: True

# %%
base = float(input("Digite a base:"))
altura = float(input("Digite a altura:"))
area = base * altura 
print("A área do quadrilatero é: ", area)
# Out:
# Digite a base: 12
# Digite a altura: 13
# A área do quadrilatero é:  156.0
